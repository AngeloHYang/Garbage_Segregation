# %% [markdown]
# # **Viewing classes in Directory**

# %%
import os
import matplotlib.pyplot as plt
from PIL import Image
import math

#dir_example = "/content/drive/My Drive/Data"
dir_example = "./Data/"

classes = os.listdir(dir_example)
print(classes)
# Out:
# ['Test', 'README.md', 'Train']

# %%
dir_example = "./Data/Train"

train_classes = os.listdir(dir_example)
print(train_classes)
# Out:
# ['glass', 'plastic', 'cardboard', 'metal', 'paper', 'trash']

# %% [markdown]
# # **Visualizing Images in Dataset from each class**

# %%
dir_with_examples = './visualize/'
files_per_row = 6
files_in_dir = os.listdir(dir_with_examples)
number_of_cols = files_per_row
number_of_rows = int(len(files_in_dir) / number_of_cols)

# Generate the subplots
fig, axs = plt.subplots(number_of_rows, number_of_cols)
fig.set_size_inches(20, 15, forward=True)

# Map each file to subplot
try:
  for i in range(0, len(files_in_dir)):
    file_name = files_in_dir[i]
    image = Image.open(f'{dir_with_examples}/{file_name}')
    row = math.floor(i / files_per_row)
    col = i % files_per_row
    axs[col].imshow(image)
    axs[col].axis('off')
except:
  pass
# Show the plot
plt.show()

# %% [markdown]
# # **Importing required Libraries for Model**

# %%
from tensorflow.keras.models import Sequential
from keras.layers import Conv2D, Flatten, MaxPooling2D, Dense, Dropout, SpatialDropout2D
from tensorflow.keras.losses import sparse_categorical_crossentropy, binary_crossentropy
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# Out:
# 2021-12-14 13:16:21.165822: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2021-12-14 13:16:21.165843: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %% [markdown]
# # **Data Configuration**

# %%
train = './Data/Train'
test = './Data/Test'

# %% [markdown]
# # **Data Preparation and Loading**

# %% [markdown]
# ### *Creating a Generator for Training Set*

# %%
train_generator = ImageDataGenerator(rescale = 1/255)

train_generator = train_generator.flow_from_directory(train,
                                                      target_size = (300,300),
                                                      batch_size = 32,
                                                      class_mode = 'sparse')

labels = (train_generator.class_indices)
print(labels,'\n')

labels = dict((v,k) for k,v in labels.items())
print(labels)
# Out:
# Found 2184 images belonging to 6 classes.
# {'cardboard': 0, 'glass': 1, 'metal': 2, 'paper': 3, 'plastic': 4, 'trash': 5}
#
# {0: 'cardboard', 1: 'glass', 2: 'metal', 3: 'paper', 4: 'plastic', 5: 'trash'}

# %% [markdown]
# ### *Creating a Generator for Testing Set*

# %%
test_generator = ImageDataGenerator(rescale = 1./255)

test_generator = test_generator.flow_from_directory(test,
                                                    target_size = (300,300),
                                                    batch_size = 32,
                                                    class_mode = 'sparse')

test_labels = (test_generator.class_indices)
print(test_labels,'\n')

test_labels = dict((v,k) for k,v in test_labels.items())
print(test_labels)
# Out:
# Found 343 images belonging to 6 classes.
# {'cardboard': 0, 'glass': 1, 'metal': 2, 'paper': 3, 'plastic': 4, 'trash': 5}
#
# {0: 'cardboard', 1: 'glass', 2: 'metal', 3: 'paper', 4: 'plastic', 5: 'trash'}

# %%
for image_batch, label_batch in train_generator:
  break
image_batch.shape, label_batch.shape
# Out:
# ((32, 300, 300, 3), (32,))

# %%
for image_batch, label_batch in test_generator:
  break
image_batch.shape, label_batch.shape
# Out:
# ((32, 300, 300, 3), (32,))

# %% [markdown]
# # **Writing the labels into a text file '*Labels.txt* '**

# %%
print(train_generator.class_indices)
Labels = '\n'.join(sorted(train_generator.class_indices.keys()))

with open('Labels.txt', 'w') as file:
  file.write(Labels)
# Out:
# {'cardboard': 0, 'glass': 1, 'metal': 2, 'paper': 3, 'plastic': 4, 'trash': 5}

# %% [markdown]
# # **Model Architecture**

# %%
model=Sequential()

#Convolution blocks
model.add(Conv2D(32, kernel_size = (3,3), padding='same',input_shape=(300,300,3),activation='relu'))
model.add(MaxPooling2D(pool_size=2)) 

model.add(Conv2D(64, kernel_size = (3,3), padding='same',activation='relu'))
model.add(MaxPooling2D(pool_size=2)) 

model.add(Conv2D(32, kernel_size = (3,3), padding='same',activation='relu'))
model.add(MaxPooling2D(pool_size=2)) 

#Classification layers
model.add(Flatten())

model.add(Dense(64,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(32,activation='relu'))

model.add(Dropout(0.2))
model.add(Dense(6,activation='softmax'))


model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 300, 300, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 150, 150, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 150, 150, 64)      18496
#
#  max_pooling2d_1 (MaxPooling  (None, 75, 75, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 75, 75, 32)        18464
#
#  max_pooling2d_2 (MaxPooling  (None, 37, 37, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 43808)             0
#
#  dense (Dense)               (None, 64)                2803776
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 6)                 198
#
# =================================================================
# Total params: 2,843,910
# Trainable params: 2,843,910
# Non-trainable params: 0
# _________________________________________________________________
# 2021-12-14 13:16:34.463847: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2021-12-14 13:16:34.463889: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (TM1701-220375b1): /proc/driver/nvidia/version does not exist
# 2021-12-14 13:16:34.464421: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # **Model Compilation**

# %%
model.compile(optimizer = 'Adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# # **Training the Model (batch_size = 32, epochs = 10)**

# %%
# %time model.fit_generator(train_generator, epochs=10, steps_per_epoch=2184//32)
# Out:
# <timed eval>:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Epoch 1/10
#  1/68 [..............................] - ETA: 1:01 - loss: 1.7912 - accuracy: 0.0000e+00
# 2021-12-14 13:16:40.386014: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 368640000 exceeds 10% of free system memory.
# 2021-12-14 13:16:41.315576: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 368640000 exceeds 10% of free system memory.
#  2/68 [..............................] - ETA: 1:23 - loss: 2.2195 - accuracy: 0.1500
# 2021-12-14 13:16:41.646488: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 368640000 exceeds 10% of free system memory.
# 2021-12-14 13:16:42.562635: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 368640000 exceeds 10% of free system memory.
#  3/68 [>.............................] - ETA: 1:21 - loss: 2.1844 - accuracy: 0.1528
# 2021-12-14 13:16:42.894005: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 368640000 exceeds 10% of free system memory.
# 68/68 [==============================] - 117s 2s/step - loss: 1.7432 - accuracy: 0.2402
# Epoch 2/10
# 68/68 [==============================] - 117s 2s/step - loss: 1.4972 - accuracy: 0.3796
# Epoch 3/10
# 68/68 [==============================] - 116s 2s/step - loss: 1.3188 - accuracy: 0.4661
# Epoch 5/10
# 68/68 [==============================] - 116s 2s/step - loss: 1.1977 - accuracy: 0.5288
# Epoch 6/10
# 68/68 [==============================] - 116s 2s/step - loss: 1.1061 - accuracy: 0.5776
# Epoch 7/10
# 68/68 [==============================] - 116s 2s/step - loss: 0.9833 - accuracy: 0.6222
# Epoch 8/10
# 68/68 [==============================] - 116s 2s/step - loss: 0.9051 - accuracy: 0.6575
# Epoch 9/10
# 68/68 [==============================] - 116s 2s/step - loss: 0.7534 - accuracy: 0.7235
# Epoch 10/10
# 68/68 [==============================] - 116s 2s/step - loss: 0.6880 - accuracy: 0.7560
# CPU times: user 1h 52min 12s, sys: 12min 44s, total: 2h 4min 56s
# Wall time: 19min 24s

# %% [markdown]
# # **Testing Predictions**

# %%
from keras.preprocessing import image
import numpy as np
test_img = './Data/Test/metal/metal363.jpg'
img = image.load_img(test_img, target_size = (300,300))
img = image.img_to_array(img, dtype=np.uint8)
img = np.array(img)/255.0
prediction = model.predict(img[np.newaxis, ...])

#print("Predicted shape",p.shape)
print("Probability:",np.max(prediction[0], axis=-1))
predicted_class = labels[np.argmax(prediction[0], axis=-1)]
print("Classified:",predicted_class,'\n')

plt.axis('off')
plt.imshow(img.squeeze())
plt.title("Loaded Image")
# Out:
# Probability: 0.25783423
# Classified: metal
# Text(0.5, 1.0, 'Loaded Image')

# %%
classes = []
probability = []

for i,j in enumerate(prediction[0],0):
  print(labels[i].upper(),':',round(j*100,2),'%')
# Out:
# CARDBOARD : 3.95 %
# GLASS : 25.6 %
# METAL : 25.78 %
# PAPER : 6.12 %
# PLASTIC : 14.37 %
# TRASH : 24.17 %

# %%
test_img = './Data/Test/glass/glass421.jpg'
img = image.load_img(test_img, target_size = (300,300))
img = image.img_to_array(img, dtype=np.uint8)
img = np.array(img)/255.0
prediction = model.predict(img[np.newaxis, ...])

#print("Predicted shape",p.shape)
print("Probability:",np.max(prediction[0], axis=-1))
predicted_class = labels[np.argmax(prediction[0], axis=-1)]
print("Classified:",predicted_class,'\n')

plt.axis('off')
plt.imshow(img.squeeze())
plt.title("Loaded Image")
# Out:
# Probability: 0.8330386
# Classified: glass
# Text(0.5, 1.0, 'Loaded Image')

# %%
classes = []
probability = []

for i,j in enumerate(prediction[0],0):
  print(labels[i].upper(),':',round(j*100,2),'%')
# Out:
# CARDBOARD : 1.26 %
# GLASS : 83.3 %
# METAL : 3.52 %
# PAPER : 0.54 %
# PLASTIC : 11.36 %
# TRASH : 0.02 %

# %%
test_img = './Data/Test/plastic/plastic425.jpg'
img = image.load_img(test_img, target_size = (300,300))
img = image.img_to_array(img, dtype=np.uint8)
img = np.array(img)/255.0
prediction = model.predict(img[np.newaxis, ...])

#print("Predicted shape",p.shape)
print("Probability:",np.max(prediction[0], axis=-1))
predicted_class = labels[np.argmax(prediction[0], axis=-1)]
print("Classified:",predicted_class,'\n')

plt.axis('off')
plt.imshow(img.squeeze())
plt.title("Loaded Image")
# Out:
# Probability: 0.8369513
# Classified: plastic
# Text(0.5, 1.0, 'Loaded Image')

# %%
classes = []
probability = []

for i,j in enumerate(prediction[0],0):
  print(labels[i].upper(),':',round(j*100,2),'%')
# Out:
# CARDBOARD : 0.26 %
# GLASS : 5.29 %
# METAL : 0.79 %
# PAPER : 9.8 %
# PLASTIC : 83.7 %
# TRASH : 0.15 %

# %% [markdown]
# ### *Testing shows that the model is fairly successful in classifying the type of waste*

# %% [markdown]
# ## ***Saving model as 'model.h5'***

# %%
model.save('weights/model.h5')
